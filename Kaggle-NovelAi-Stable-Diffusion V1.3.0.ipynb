# %% [markdown]
# ## NovelAi stable-diffusion-webui+api 修复版（Kaggle云端部署项目，完全免费，无需任何配置！）
# **torch: 1.13.1+cu117  •  xformers: 0.0.16rc425**

# %% [markdown]
# <a href="https://sm.ms/image/fnCzAYw1FksqZEW" target="_blank"><img src="https://s2.loli.net/2023/02/06/fnCzAYw1FksqZEW.png" /></a>
# Kaggle在线部署NovelAi（Webui）的生成演示效果，与本地部署效果几乎一致。模型：AbyssOrange_mix2_nsfw

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana;">
#     📌 2023年3月5日更新：现在支持通过下载链接上传模型了，省去了下载模型后再上传后的麻烦.（）
# </div>

# %% [markdown]
# # 注意事项/WARNING：
#
# - ### 此项目为yiyiooo作者所写的，本人修改了一些内容，使用的是旧版的启动方式，新版无法启动，原因未知
# - ### 此项目为修复版内容，目前部分功能不可用，例如maple的tag选择器扩展
# - ### 将设置中的PERSISTENCE改为Files Only方便下次打开提高启动速度，第一次启动后下载Python环境包就不用下载第二次了
#
# # **DO NOT GENGRATE <span style="color:crimson;">NSFW</span> IMAGE**
# # <span style="color:crimson;">**请勿生成违规图片！**</span>

# %% [markdown]
# <center style="font-family:cursive; font-size:18px; color:#159364;">以下是代码区域</center>

# %% [markdown]
# ---
# # **第一个代码单元格：**
#  ### 重要区域，换模型，装扩展都在此处，可以根据自己需求改

# %%
#第一个代码单元格，可以根据自己的需求进行更改

#通过下载链接下载模型，支持C站和Huggingface上面的模型，不能带空格
modelurl = 'https://huggingface.co/ckpt/anything-v4.5-vae-swapped/resolve/main/anything-v4.5-vae-swapped.safetensors'
name = 'Anything-V4.5.safetensors'#你所下载模型的名称，必填，不能带空格,记得带上模型的后缀(safetensors/ckpt)

useNgrok=False # 非必填 是否使用ngrok作为公网访问地址
ngrokTokenFile='/kaggle/input/configs/ngrok_token.txt' # 非必填 存放ngrokToken的文件的路径
useFrpc=True
frpcConfigFile='/kaggle/input/frpcfile/frpc_7860.ini'    # 非必填 frp 配置文件
disableShared=False # 关闭默认的gradio.live穿透，如果没有配置ngrok或frp不要开启这个选项

# 模型目录 
# Stable Diffusion模型请放在这里（不用填模型的文件名，只填模型的目录即可）
modelDirs = []
# 启动时默认加载的模型名称 可填全路径或者模型名称，名称建议带上文件名后缀
# 如果你想加载7G以上的大模型，请填这个来加载，直接在Webui里切换模型容易爆内存
usedCkpt = ''
# Hypernetworks超网络模型路径请放在这里：
hypernetworksModelDirs = []
# embeddings（pt文件）请放在这里:
embeddingsModelDirs = [] 
# Lora模型的数据集路径请写在这里：
loraModelDirs = [] 
# 此配置内的目录下所有文件将加载到wildcards文件夹
wildcardsFileDirs = [] 

# ControlNet模型请放在这里：
Controlnet = []

# 将Lora模型放在可选附加网络扩展（占用内存高，拖慢启动速度。请注意！！）
AdditionalNetworks = []

# 插件列表： git仓库地址
# 开启公网访问后将不能在webui界面安装插件，如果有需要安装的插件，把地址加入到下面
# 不需要的插件在前面加 # ，插件地址之间需要用英语逗号隔开
extensions = [
    # krita 绘图软件插件
    #'https://github.com/Interpause/auto-sd-paint-ext',
    # 汉化 对新功能没有完全覆盖
    'https://github.com/2575044704/stable-diffusion-webui-localization-zh_CN', 
    # 图片浏览器 不安装不能在webui界面查看图片
    'https://github.com/yfszzx/stable-diffusion-webui-images-browser', 
    # 自动tag补全插件 tag翻译文件在webui_settings这个配置里
    'https://github.com/DominikDoom/a1111-sd-webui-tagcomplete', 
    # 此插件会过滤重复标签和空标签、会将中文的逗号和括号替换成英文的逗号或括号，可能影响tag权重
    'https://github.com/viyiviyi/filter-empty-prompts.git', 
    # 可以使用__加文件名的方式从文件中随机读取一行加入到tag
    #'https://github.com/AUTOMATIC1111/stable-diffusion-webui-wildcards', 
    # 提示词变迁插件 没用过 -_-
    'https://github.com/Kahsolt/stable-diffusion-webui-prompt-travel.git' ,
    #美术风格
    'https://github.com/AUTOMATIC1111/stable-diffusion-webui-aesthetic-gradients.git',
    # Lora的扩展（占内存，慎用）
    #'https://github.com/kohya-ss/sd-webui-additional-networks',
    # ControlNet
    'https://github.com/Mikubill/sd-webui-controlnet',
    # OpenPose
    'https://github.com/fkunn1326/openpose-editor'
]

# webui的配置文件 因为有比较多的人在用了，而个人喜好又不一样，所以这里可以使用自己的配置文件
# 需要使用git仓库 需要将对应的文件放在仓库的 dist目录下，dist目录下的全部文件都会被复制到webui的根目录
webui_settings = 'https://github.com/2575044704/sd-configs2.git'
# 设置文件路径  默认使用 webui_settings 里面的config.json 和 ui-config.json文件
setting_file = '/kaggle/input/configs/config.json'
ui_config_file = '/kaggle/input/configs/ui-config.json'
otherArgs = '' # '--api-auth=2333:6666 --gradio-auth=2333:6666' # 其他需要加载的webui启动参数
#VAE相关，一般不用改，这个vae色彩度很高
zheshiVAEwenjian = 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt'
address = 'orangemix.vae.pt'
# koishi相关
useKoishi = False # 是否开启Koishi机器人
koishiPort = 5140 # 使用7860将会占用webui的默认端口
# 如果这个配置文件与上面的配置文件相同，可能会出问题
koishiFrpcConfig = '/kaggle/input/frpcfile/frpc_5140.ini'
# 可以将输出目录的文件下载后上传到数据集，下次启动就不用再配置一次
koishiPath = '/kaggle/input/koishirepair/kaggle/koishi'
#机器人登不上的时候可以用这个转移account文件
account = '/kaggle/input/2302594520'

# %% [markdown]
# ---
# # **第二个代码单元格：**
#  ### 不常用设置，一般不用改

# %%
#第二个代码单元格，此处的设置一般不用动

# 手机端界面优化 使用了修改过界面布局顺序的webui，不定期同步到官方版本
mobileOptimize=False
# 安装目录 如果安装目录在输出目录（/kaggle/working）下，建议不要开启 Save Version 功能，因为每次结束运行都需要等待上传全部文件
install_path="/kaggle" 
# 输出目录 默认将 图片输出目录和图片收藏目录连接到此目录下 可以在下方 【配置文件链接】 处开启链接其他文件夹（完全没有必要）
output_path="/kaggle/working"

# 配置启动参数
quickStart=True # 快速启动 使用下载好的python环境 开启后启动到可用需要4分钟,不开启需要8分钟
vaeHalf=False # vae开启半精度，关闭效果更好，对速度没啥影响
modelHalf=True # 模型开启半精度，关闭效果更好，但生成速度减半
consoleProgressbars=False # 控制台显示进度条，关闭可以减少一些输出内容，查看日志时更快一点
consolePrompts=False # 同上 
enableLoadByCopy=False # 是否使用copy的方式加载文件 启动变慢，且测试后没有提高模型切换速度

# 配置文件链接
linkHypernetworksDir=False # 链接 hypernetworks 目录到输出目录 如果需要训练 hypernetworks 时建议开启
linkEmbeddingsDir=False # 链接 embeddings 目录到输出目录 如果需要训练 embeddings 时建议开启
linkTextual_inversionDir=False # 链接 textual_inversion 目录到输出目录 如果需要保存训练过程的产出文件时建议开启

# 这下面的是用于初始化一些值或者环境变量的，轻易别改
from pathlib import Path
import os
import time
import re
if not Path(frpcConfigFile).exists(): useFrpc = False
os.environ['install_path'] = install_path
os.environ['output_path'] = output_path
os.environ['webui_settings'] = webui_settings
os.environ['frpcConfig'] = frpcConfigFile

ngrokToken=''
if Path(ngrokTokenFile).exists():
    with open(ngrokTokenFile,encoding = "utf-8") as nkfile:
        ngrokToken = nkfile.readline()

# %%
# 重置变量 用于修改参数后重新安装
reLoad = True
# 如果需要重新安装，请注释这一行
reLoad = False

# %% [markdown]
# ---
# # **第三个代码单元格：**
#  ### Koishi机器人项目（已修复！能用了！）

# %%
# Koishi https://koishi.chat/
def installKoishi():
    # !echo '安装koishi和相关依赖'
    # %cd $install_path
    # !mkdir -p koishi
    # %cd koishi
    # !apt-get update
    # !apt-get install chromium-browser -y
    if Path(koishiPath).exists():
        os.system('cp -rf -n '+koishiPath+'/* ./')
        # !cp -rf {account} $install_path/koishi/accounts
    else:
        # !npm init -y
        # !npm i koishi -D
        # !npx koishi init
        # !npm i @koishijs/plugin-logger @koishijs/plugin-market @koishijs/plugin-console -D
        # !npm i @koishijs/plugin-auth @koishijs/plugin-status @koishijs/plugin-insight -D
    # !npm i
def startKoishi():
    # %cd $install_path/koishi
    if Path('koishi.config.yml').exists():
        # !pm2 del koishi
        # !pm2 start npx -n koishi -- koishi start koishi.config.yml
        return
    content = f'''
# 全局设置
host: localhost
# 端口
port: {koishiPort}
# 插件列表
plugins:
  # group 表示这是一个插件组
  group:console:
    # 波浪线前缀表示一个不启用的插件
    auth: 
    console:
    logger:
    status:
    insight:
    market:
'''
    # !mkdir -p $install_path/koishi/
    with open('koishi.config.yml','w') as sh:
        sh.write(content)
    # !pm2 del koishi
    # !pm2 start npx -n koishi -- koishi start koishi.config.yml

def startKoishFrpc():
    # !pm2 del frpc_koishi
    os.system('pm2 start $install_path/frpc/frpc -n frpc_koishi -- -c '+koishiFrpcConfig)
    
def saveKoishi():
    # %cd /kaggle/working/
    # !tar -cvf koishi.tar --exclude=koishi/node_modules --exclude=koishi/logs $install_path/koishi 

# 每10分钟保存一次koishi的数据
def autoZipKoishiData():
    # %cd $install_path
    content = '''
setInterval(() => {
    try {
        const { exec } = require('child_process');
        exec('tar -cvf /kaggle/working/koishi.tar --exclude=koishi/node_modules --exclude=koishi/logs $install_path/koishi');
        console.log('每10分钟保存一次数据');
    } catch (error) {
        console.error('保存数据失败');
    }
}, 1000 * 60 * 10);
    '''
    with open('autoZipKoishiData.js','w') as sh:
        sh.write(content)
    # !pm2 del autoZipKoishiData
    # !pm2 start autoZipKoishiData.js -n autoZipKoishiData

# %% [markdown]
# ---
# # **第四个代码单元格：**
#  ### Webui安装

# %%
# 功能函数
# 绕过 os.systen 的限制执行命令
def run(shell:str):
    with open('run_cache.sh','w') as sh:
        sh.write(shell)
    # !bash run_cache.sh

# 连接多个路径字符串 让路径在shell命令中能正常的执行
def pathJoin(*paths:str):
    pathStr = ''
    for p in paths:
        pathStr += '"'+p+'"'
    pathStr = '"*"'.join(pathStr.split('*'))
    pathStr = '"$"'.join(pathStr.split('$'))
    pathStr = '"("'.join(pathStr.split('('))
    pathStr = '")"'.join(pathStr.split(')'))
    pathStr = '"{"'.join(pathStr.split('{'))
    pathStr = '"}"'.join(pathStr.split('}'))
    pathStr = re.sub(r'""','',pathStr)
    pathStr = re.sub(r'\*{2,}','"',pathStr)
    pathStr = re.sub(r'/{2,}','/',pathStr)
    pathStr = re.sub(r'/\./','/',pathStr)
    return pathStr

# 判断路径是不是一个文件或者可能指向一些文件
def pathIsFile(path):
    if Path(path).is_file():
        return True
    if re.search(r'\.(ckpt|safetensors|png|jpg|txt|pt|pth|json|yaml|\*)$',path):
        return True
    return False

def installEnv():
    # !npm i -g pm2

#安装webui
def install():
    # %cd $install_path
    if reLoad:
        # !rm -rf stable-diffusion-webui
    if Path("stable-diffusion-webui").exists():
        # %cd $install_path/stable-diffusion-webui/
        # !git checkout .
        # !git pull
    else:
        if mobileOptimize:
            # !git clone https://github.com/viyiviyi/stable-diffusion-webui.git -b local # 修改了前端界面，手机使用更方便
        else:
            # !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui 
        # %cd $install_path/stable-diffusion-webui/
        if quickStart:
            # !echo "解压Python环境... unzip venv"
            # !tar -xf /kaggle/working/venv/venv.tar.bak -C ./

# 链接输出目录
def link_dir():
    # 链接输出目录 因为sd被部署在了stable-diffusion-webui目录，运行结束后为了方便下载就只有outputs目录放在output_path/目录下
    # !mkdir -p $output_path/outputs
    # !rm -rf $install_path/stable-diffusion-webui/outputs
    # !ln -s -r $output_path/outputs $install_path/stable-diffusion-webui/ # 输出目录
    # !mkdir -p $output_path/log
    # !rm -rf $install_path/stable-diffusion-webui/log
    # !ln -s -r $output_path/log $install_path/stable-diffusion-webui/
    # 链接 hypernetworks 目录
    if linkHypernetworksDir:
        # !rm -rf $install_path/stable-diffusion-webui/models/hypernetworks
        # !mkdir -p $output_path/hypernetworks
        # !ln -s -r $output_path/hypernetworks $install_path/stable-diffusion-webui/models/
    # 链接 embeddings 目录
    if linkEmbeddingsDir:
        # !rm -rf $install_path/stable-diffusion-webui/embeddings
        # !mkdir -p $output_path/embeddings
        # !ln -s -r $output_path/embeddings $install_path/stable-diffusion-webui/
    # 链接训练输出目录 文件夹链接会导致功能不能用
    if linkTextual_inversionDir:
        # !rm -rf $install_path/stable-diffusion-webui/textual_inversion
        # !mkdir -p $output_path/textual_inversion/
        # !ln -s -r $output_path/textual_inversion $install_path/stable-diffusion-webui/
        
        
def venvdownload():
    if os.access("/kaggle/working/venv/venv.tar.bak", os.F_OK):
        print ("正在安装Webui")
    else:
        print("\033[1;31m 首次启动需要一点时间，请耐心等待\033[0m")
        print("\033[1;31m 自动下载Python环境包...，可能有点慢\033[0m")
        # !apt -y update -qq
        # !apt -y install -qq aria2
        # !echo '正在自动下载Python环境包'
        # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/datasets/ACCA225/vene/resolve/main/venv.tar.bak -d /kaggle/working/venv -o venv.tar.bak
        # !echo '下载成功'
    
# 链接模型文件
# link models files
def link_models():
    print(('复制' if enableLoadByCopy else '链接') + '模型文件')
    if enableLoadByCopy:
        print('如果出现 No such file or directory 错误，可以忽略')
    # !mkdir -p $install_path/stable-diffusion-webui/models/Stable-diffusion # 模型和文件目录
    # !mkdir -p $install_path/stable-diffusion-webui/models/hypernetworks # 超网络模型目录
    # !mkdir -p $install_path/stable-diffusion-webui/embeddings # 画风模型目录
    # !mkdir -p $install_path/stable-diffusion-webui/models/Lora # lora 文件目录
    # !mkdir -p $install_path/stable-diffusion-webui/extensions/stable-diffusion-webui-wildcards/wildcards # wildcards 文件目录
    # !mkdir -p $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models/ 
    # !mkdir -p $install_path/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora
    # !mkdir -p $install_path/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora # lora 文件目录
    
    for path in modelDirs:
        if pathIsFile(path):
            os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path) +' $install_path/stable-diffusion-webui/models/Stable-diffusion')
            continue
        os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path,'/*.ckpt') +' $install_path/stable-diffusion-webui/models/Stable-diffusion/')
        os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path,'/*.safetensors') +' $install_path/stable-diffusion-webui/models/Stable-diffusion/')
        os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path,'/*.png') +' $install_path/stable-diffusion-webui/models/Stable-diffusion/')
        os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path,'/*.jpg') +' $install_path/stable-diffusion-webui/models/Stable-diffusion/')
        os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path,'/*.pt') +' $install_path/stable-diffusion-webui/models/Stable-diffusion/')
        os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path,'/hypernetworks*/*.*') +' $install_path/stable-diffusion-webui/models/hypernetworks/')
        os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path,'/embeddings*/*.*') +' $install_path/stable-diffusion-webui/embeddings/')
        os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path,'/lora*/*.*') +' $install_path/stable-diffusion-webui/models/Lora/')
        os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path,'/wildcards*/*.*') +' $install_path/stable-diffusion-webui/extensions/stable-diffusion-webui-wildcards/wildcards/')
    for path in wildcardsFileDirs:
        if pathIsFile(path):
            os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path) +' $install_path/stable-diffusion-webui/extensions/stable-diffusion-webui-wildcards/wildcards/')
            continue
        os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path,'/*.*') +' $install_path/stable-diffusion-webui/extensions/stable-diffusion-webui-wildcards/wildcards/')
    for path in loraModelDirs: 
        if pathIsFile(path):
            os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path) +' $install_path/stable-diffusion-webui/models/Lora/')
            continue
        os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path,'/*.*') +' $install_path/stable-diffusion-webui/models/Lora/')
    for path in embeddingsModelDirs: 
        if pathIsFile(path):
            os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path) +' $install_path/stable-diffusion-webui/embeddings/')
            continue
        os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path,'/*.*') +' $install_path/stable-diffusion-webui/embeddings/')
    for path in hypernetworksModelDirs: 
        if pathIsFile(path):
            os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path) +' $install_path/stable-diffusion-webui/models/hypernetworks/')
            continue
        os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path,'/*.*') +' $install_path/stable-diffusion-webui/models/hypernetworks/')
    if Path(install_path+'/stable-diffusion-webui/extensions/sd-webui-controlnet').exists():
        for path in Controlnet: 
            if pathIsFile(path):
                os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path) +' $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models/')
                continue
            os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f ' + pathJoin(path,'/*.*') +' $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models/')
    if Path(install_path+'/stable-diffusion-webui/extensions/sd-webui-additional-networks').exists():
        for path in AdditionalNetworks: 
            if pathIsFile(path):
                os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f '+ pathJoin(path) +' $install_path/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/')
                continue
            os.system(('cp -n' if enableLoadByCopy else 'ln -s')+' -f ' + pathJoin(path,'/*.*') +' $install_path/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/')
            
        
    # %cd $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models/
    # !rm -f \*.* # 删除因为文件夹没有对应文件导致复制了一个'*.*'的文件
    # !echo controlnetModel文件列表
    # !ls

    # %cd $install_path/stable-diffusion-webui/models/Stable-diffusion
    # !rm -f \*.* & rm -f \*.ckpt & rm -f \*.safetensors & rm -f \*.png & rm -f \*.pt & rm -f \*.jpg # 删除因为文件夹没有对应文件导致复制了一个'*.*'的文件
    # !echo 模型文件列表
    # !ls
    # %cd $install_path/stable-diffusion-webui/models/hypernetworks
    # !rm -f \*.* # 删除因为文件夹没有对应文件导致复制了一个'*.*'的文件
    # !echo hypernetworks超网络模型文件列表
    # !ls
    # %cd $install_path/stable-diffusion-webui/embeddings
    # !rm -f \*.* # 删除因为文件夹没有对应文件导致复制了一个'*.*'的文件
    # !echo embedding文件列表
    # !ls
    # %cd $install_path/stable-diffusion-webui/models/Lora
    # !rm -f \*.* # 删除因为文件夹没有对应文件导致复制了一个'*.*'的文件
    # !echo lora文件列表
    # !ls
    # %cd $install_path/stable-diffusion-webui/extensions/stable-diffusion-webui-wildcards/wildcards
    # !rm -f \*.* # 删除因为文件夹没有对应文件导致复制了一个'*.*'的文件
    # !echo wildcards文件列表
    # !ls

#下载模型
def modelsdownload():
    # !apt -y update -qq
    # !apt -y install -qq aria2
    # !echo '正在下载模型...'
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {modelurl} -d $install_path/stable-diffusion-webui/models/Stable-diffusion -o {name}
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/embed/EasyNegative/resolve/main/EasyNegative.safetensors -d $install_path/stable-diffusion-webui/embeddings/ -o EasyNegative.safetensors
#下载VAE
def vaedownload():
    # !echo '正在下载VAE...'
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {zheshiVAEwenjian} -d $install_path/stable-diffusion-webui/models/Stable-diffusion -o {address}
    
#安装依赖
def install_dependencies():
    # %cd $install_path/stable-diffusion-webui
    # !python3 -m venv venv
    # !source venv/bin/activate
    # !COMMANDLINE_ARGS="--exit" REQS_FILE="requirements.txt" venv/bin/python3  launch.py

# 安装插件
def install_extensions():
    print('安装插件，此处出现红条是正常的')
    # %cd $install_path/stable-diffusion-webui
    # !mkdir -p extensions
    # %cd extensions
    for ex in extensions:
        os.system('git clone '+ex)
    #Tag选择器
    # !cp -r /kaggle/input/tagextensions/maple-from-fall-and-flower $install_path/stable-diffusion-webui/extensions/maple-from-fall-and-flower
    
# 个性化配置 
def use_config():
    # %cd $install_path/stable-diffusion-webui
    # !mkdir -p tmp
    # %cd tmp
    # !git clone $webui_settings sd-configs
    # !cp -rf sd-configs/dist/* $install_path/stable-diffusion-webui
     
# ngrok
def ngrok_start():
    if useNgrok == True and ngrokToken != '':
        print('use nrgok')
        # !pip install pyngrok
        from pyngrok import conf, ngrok
        conf.get_default().auth_token = ngrokToken
        conf.get_default().monitor_thread = False
        ssh_tunnels = ngrok.get_tunnels(conf.get_default())
        if len(ssh_tunnels) == 0:
            ssh_tunnel = ngrok.connect(7860)
            print('address：'+ssh_tunnel.public_url)
        else:
            print('address：'+ssh_tunnels[0].public_url)
    else:
        print('skip start ngrok')
        
def installFrpc():
    # !apt -y update -qq
    # !apt -y install -qq aria2
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/datasets/ACCA225/Frp/resolve/main/frpc -d $install_path/stable-diffusion-webui/ -o frpc
    # %cd $install_path
    # !mkdir -p frpc
    # %cd frpc
    # !cp -f -n $install_path/stable-diffusion-webui/frpc ./frpc
    # !chmod +x ./frpc
    # !./frpc -v
    
def startFrpc():
    if useFrpc:
        # !pm2 del frpc_webui
        # !pm2 start $install_path/frpc/frpc -n frpc_webui -- -c $frpcConfig
        
def installBore():
    # %cd $install_path
    # !mkdir -p bore
    # %cd bore
    # !cp -f -n /kaggle/input/net-tools/bore ./bore
    # !chmod +x ./bore

def startBore():
    # !pm2 del bore
    # !pm2 start $install_path/bore/bore -n bore -- local 5140 --to bore.pub
    
# 打包输出图片到$output_path/outputs.tar文件
def zip_output():
    # !echo "打包输出图片到$output_path/outputs.tar文件"
    # %cd $install_path/stable-diffusion-webui/
    # !tar -cf outputs.tar ./outputs
    # !mv ./outputs.tar $output_path/
    
# 启动
def start():
    # %cd $install_path/stable-diffusion-webui
    # !python3 -m venv venv
    # !source venv/bin/activate
    args = '--disable-safe-unpickle --deepdanbooru'
    if not disableShared:
        args += ' --share'
    args += ' --skip-torch-cuda-test'
    args += ' --xformers' # 已经可用
    args += ' --api --listen' # 开放 api
    args += ' --lowram' # 降低爆内存几率
    if ui_config_file is not None and ui_config_file != '' and Path(ui_config_file).exists(): # ui配置文件
        args += ' --ui-config-file=' + pathJoin(ui_config_file)
    if setting_file is not None and setting_file != '' and Path(setting_file).exists(): # 设置配置文件
        args += ' --ui-settings-file=' + pathJoin(setting_file)
    if usedCkpt is not None and usedCkpt != '': # 设置启动时默认加载的模型
        if '.' in usedCkpt:
            if '/' in usedCkpt:
                args += ' --ckpt='+ pathJoin(usedCkpt)
            else:
                args += ' --ckpt='+ pathJoin(install_path, '/stable-diffusion-webui/models/Stable-diffusion/', usedCkpt)
        else:
            for x in ['.ckpt','.safetensors']:
                if Path(install_path+'/stable-diffusion-webui/models/Stable-diffusion/' + usedCkpt+x).exists():
                    args += ' --ckpt='+ pathJoin(install_path, '/stable-diffusion-webui/models/Stable-diffusion/', usedCkpt, x)
                    break
    if vaeHalf is False: 
        args += ' --no-half-vae'
    if modelHalf is False:
        args += ' --no-half'
    if consoleProgressbars is False:
        args += ' --disable-console-progressbars'
    if consolePrompts is True:
        args += ' --enable-console-prompts'
    args += ' ' + otherArgs
    os.environ['COMMANDLINE_ARGS']=args
    # !echo COMMANDLINE_ARGS=$COMMANDLINE_ARGS
    # %env REQS_FILE=requirements.txt
    # !pm2 log & venv/bin/python3 launch.py
    
def start():
    # %cd $install_path/stable-diffusion-webui
    # !python3 -m venv venv
    # !source venv/bin/activate
    args = '--disable-safe-unpickle --deepdanbooru'
    if not disableShared:
        args += ' --share'
    args += ' --skip-torch-cuda-test'
    args += ' --xformers' # 已经可用
    args += ' --api --listen' # 开放 api
    args += ' --lowram'# 降低爆内存几率
    if ui_config_file is not None and ui_config_file != '' and Path(ui_config_file).exists(): # ui配置文件
        args += ' --ui-config-file=' + pathJoin(ui_config_file)
    if setting_file is not None and setting_file != '' and Path(setting_file).exists(): # 设置配置文件
        args += ' --ui-settings-file=' + pathJoin(setting_file)
    if usedCkpt is not None and usedCkpt != '': # 设置启动时默认加载的模型
        if '.' in usedCkpt:
            if '/' in usedCkpt:
                args += ' --ckpt='+ pathJoin(usedCkpt)
            else:
                args += ' --ckpt='+ pathJoin(install_path, '/stable-diffusion-webui/models/Stable-diffusion/', usedCkpt)
        else:
            for x in ['.ckpt','.safetensors']:
                if Path(install_path+'/stable-diffusion-webui/models/Stable-diffusion/' + usedCkpt+x).exists():
                    args += ' --ckpt='+ pathJoin(install_path, '/stable-diffusion-webui/models/Stable-diffusion/', usedCkpt, x)
                    break
    if vaeHalf is False: 
        args += ' --no-half-vae'
    if modelHalf is False:
        args += ' --no-half'
    if consoleProgressbars is False:
        args += ' --disable-console-progressbars'
    if consolePrompts is True:
        args += ' --enable-console-prompts'
    args += ' ' + otherArgs
    os.environ['COMMANDLINE_ARGS']=args
    # !echo COMMANDLINE_ARGS=$COMMANDLINE_ARGS
    # %env REQS_FILE=requirements.txt
    # !venv/bin/python3 -m pip install gradio==3.19.0
    # !pm2 log & venv/bin/python3 launch.py
    
def autosave():
    # !tar -cvf /kaggle/working/输出内容.tar /kaggle/working/outputs
    # !echo "图片已保存至输出目录"
    
def main():
    startTicks = time.time()
    isInstall = True if os.getenv('IsInstall','False') == 'True' else False
    if isInstall is False or reLoad:
        venvdownload()
        install()
        install_dependencies()
        install_extensions()
        installEnv()
        use_config()
        link_dir()
        installFrpc()
        if useKoishi:
            installKoishi()
        isInstall = True
        os.environ['IsInstall'] = 'True'
    modelsdownload()
    vaedownload()
    link_models()
    ticks = time.time()
    print("加载耗时:",(ticks - startTicks),"s")
    ngrok_start()
    startFrpc()
    if useKoishi:
        startKoishFrpc()
        startKoishi()
        autoZipKoishiData()
    start()

# %% [markdown]
# ---
# # **第五个代码单元格：**
#  ### 输出日志

# %%
# 启动的输出日志，等待约5分钟，最终会得到一个gradio.live的链接，但如果出现Error这个词，说明出错了。请联系管理员解决该问题
# start
main()

if useKoishi:
    saveKoishi()
# Out:
#  首次启动需要一点时间，请耐心等待
#  自动下载Python环境包...，可能有点慢
# 78 packages can be upgraded. Run 'apt list --upgradable' to see them.
# The following additional packages will be installed:
#   libaria2-0 libc-ares2 libssh2-1
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2 libssh2-1
# 0 upgraded, 4 newly installed, 0 to remove and 78 not upgraded.
# Need to get 1550 kB of archives.
# After this operation, 6235 kB of additional disk space will be used.
#
# 78Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 111522 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.15.0-1ubuntu0.2_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  6%] [###.......................................................] 8Unpacking libc-ares2:amd64 (1.15.0-1ubuntu0.2) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libssh2-1:amd64.
# Preparing to unpack .../libssh2-1_1.8.0-2.1build1_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libssh2-1:amd64 (1.8.0-2.1build1) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.35.0-1build1_amd64.deb ...
# 7Progress: [ 29%] [#################.........................................] 8Unpacking libaria2-0:amd64 (1.35.0-1build1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.35.0-1build1_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking aria2 (1.35.0-1build1) ...
# 7Progress: [ 47%] [###########################...............................] 8Setting up libc-ares2:amd64 (1.15.0-1ubuntu0.2) ...
# 7Progress: [ 53%] [##############################............................] 87Progress: [ 59%] [##################################........................] 8Setting up libssh2-1:amd64 (1.8.0-2.1build1) ...
# 7Progress: [ 65%] [#####################################.....................] 87Progress: [ 71%] [########################################..................] 8Setting up libaria2-0:amd64 (1.35.0-1build1) ...
# 7Progress: [ 76%] [############################################..............] 87Progress: [ 82%] [###############################################...........] 8Setting up aria2 (1.35.0-1build1) ...
# 7Progress: [ 88%] [###################################################.......] 87Progress: [ 94%] [######################################################....] 8Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
#
# 78正在自动下载Python环境包
# [#8c5330 4.4GiB/4.4GiB(99%) CN:15 DL:277MiB]0m]m
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 8c5330|OK  |   289MiB/s|/kaggle/working/venv/venv.tar.bak
#
# Status Legend:
# (OK):download completed.
# 下载成功
# /kaggle
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 17850, done.
# remote: Total 17850 (delta 0), reused 0 (delta 0), pack-reused 17850
# Receiving objects: 100% (17850/17850), 28.25 MiB | 28.45 MiB/s, done.
# Resolving deltas: 100% (12502/12502), done.
# /kaggle/stable-diffusion-webui
# 解压Python环境... unzip venv
# /kaggle/stable-diffusion-webui
# Python 3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:53)
# [GCC 9.4.0]
# Commit hash: 22bcc7be428c94e9408f589966c2040187245d81
# Cloning Stable Diffusion into /kaggle/stable-diffusion-webui/repositories/stable-diffusion-stability-ai...
# Cloning Taming Transformers into /kaggle/stable-diffusion-webui/repositories/taming-transformers...
# Cloning K-diffusion into /kaggle/stable-diffusion-webui/repositories/k-diffusion...
# Cloning CodeFormer into /kaggle/stable-diffusion-webui/repositories/CodeFormer...
# Cloning BLIP into /kaggle/stable-diffusion-webui/repositories/BLIP...
# Installing requirements for Web UI
# ^C
# 安装插件，此处出现红条是正常的
# /kaggle/stable-diffusion-webui
# /kaggle/stable-diffusion-webui/extensions
# Cloning into 'stable-diffusion-webui-localization-zh_CN'...
# Cloning into 'stable-diffusion-webui-images-browser'...
# Cloning into 'a1111-sd-webui-tagcomplete'...
# Cloning into 'filter-empty-prompts'...
# Cloning into 'stable-diffusion-webui-prompt-travel'...
# Cloning into 'stable-diffusion-webui-aesthetic-gradients'...
# Cloning into 'sd-webui-controlnet'...
# Cloning into 'openpose-editor'...
# cp: cannot stat '/kaggle/input/tagextensions/maple-from-fall-and-flower': No such file or directory
# npm WARN deprecated uuid@3.4.0: Please upgrade  to version 7 or higher.  Older versions may use Math.random() in certain circumstances, which is known to be problematic.  See https://v8.dev/blog/math-random for details.
# m##################) ⠴ reify:dayjs: http fetch GET 200 https://registry.npmjs.opmjs.omjs
# added 184 packages, and audited 185 packages in 9s
#
# 12 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities
# npm notice
# npm notice New major version of npm available! 8.19.2 -> 9.6.3
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v9.6.3
# npm notice Run npm install -g npm@9.6.3 to update!
# npm notice
# /kaggle/stable-diffusion-webui
# /kaggle/stable-diffusion-webui/tmp
# Cloning into 'sd-configs'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 31 (delta 7), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (31/31), 1.13 MiB | 6.83 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# 78 packages can be upgraded. Run 'apt list --upgradable' to see them.
# aria2 is already the newest version (1.35.0-1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 78 not upgraded.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# cb5b9a|OK  |    12MiB/s|/kaggle/stable-diffusion-webui//frpc
#
# Status Legend:
# (OK):download completed.
# /kaggle
# /kaggle/frpc
# 0.45.0-sakura-2.3
# 78 packages can be upgraded. Run 'apt list --upgradable' to see them.
# aria2 is already the newest version (1.35.0-1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 78 not upgraded.
# 正在下载模型...
# [#fd7f9c 3.8GiB/3.9GiB(95%) CN:16 DL:187MiB]0m]m
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# fd7f9c|OK  |   235MiB/s|/kaggle/stable-diffusion-webui/models/Stable-diffusion/Anything-V4.5.safetensors
#
# Status Legend:
# (OK):download completed.
# [#3d18c0 0B/24KiB(0%) CN:1 DL:0B]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3d18c0|OK  |   4.5KiB/s|/kaggle/stable-diffusion-webui/embeddings//EasyNegative.safetensors
#
# Status Legend:
# (OK):download completed.
# 正在下载VAE...
# [#224f57 481MiB/784MiB(61%) CN:16 DL:266MiB ETA:1s]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 224f57|OK  |   297MiB/s|/kaggle/stable-diffusion-webui/models/Stable-diffusion/orangemix.vae.pt
#
# Status Legend:
# (OK):download completed.
# 链接模型文件
# /kaggle/stable-diffusion-webui/extensions/sd-webui-controlnet/models
# controlnetModel文件列表
# cldm_v15.yaml		 t2iadapter_color_sd14v1.yaml
# cldm_v21.yaml		 t2iadapter_keypose_sd14v1.yaml
# image_adapter_v14.yaml	 t2iadapter_style_sd14v1.yaml
# sketch_adapter_v14.yaml
# /kaggle/stable-diffusion-webui/models/Stable-diffusion
# 模型文件列表
#  Anything-V4.5.safetensors		      orangemix.vae.pt
# 'Put Stable Diffusion checkpoints here.txt'
# /kaggle/stable-diffusion-webui/models/hypernetworks
# hypernetworks超网络模型文件列表
# /kaggle/stable-diffusion-webui/embeddings
# embedding文件列表
#  EasyNegative.safetensors  'Place Textual Inversion embeddings here.txt'
# /kaggle/stable-diffusion-webui/models/Lora
# lora文件列表
# /kaggle/stable-diffusion-webui/extensions/stable-diffusion-webui-wildcards/wildcards
# wildcards文件列表
# 加载耗时: 203.25477075576782 s
# skip start ngrok
# /kaggle/stable-diffusion-webui
# COMMANDLINE_ARGS=--disable-safe-unpickle --deepdanbooru --share --skip-torch-cuda-test --xformers --api --listen --lowram --no-half-vae --disable-console-progressbars
# env: REQS_FILE=requirements.txt
# Collecting gradio==3.19.0
#   Downloading gradio-3.19.0-py3-none-any.whl (14.2 MB)
#      |████████████████████████████████| 14.2 MB 4.8 MB/s eta 0:00:01
# Requirement already satisfied: websockets>=10.0 in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (10.4)
# Requirement already satisfied: altair>=4.2.0 in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (4.2.2)
# Requirement already satisfied: httpx in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (0.23.3)
# Requirement already satisfied: markupsafe in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (2.1.2)
# Requirement already satisfied: aiohttp in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (3.8.3)
# Requirement already satisfied: requests in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (2.28.2)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (0.3.3)
# Requirement already satisfied: ffmpy in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (0.3.0)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (3.1.2)
# Requirement already satisfied: pydub in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (0.25.1)
# Requirement already satisfied: numpy in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (1.21.6)
# Requirement already satisfied: uvicorn in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (0.20.0)
# Requirement already satisfied: matplotlib in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (3.5.3)
# Requirement already satisfied: pandas in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (1.3.5)
# Requirement already satisfied: aiofiles in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (22.1.0)
# Requirement already satisfied: python-multipart in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (0.0.4)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (2.1.0)
# Requirement already satisfied: fastapi in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (0.89.1)
# Requirement already satisfied: pydantic in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (1.10.4)
# Requirement already satisfied: pillow in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (9.4.0)
# Requirement already satisfied: orjson in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (3.8.5)
# Requirement already satisfied: pyyaml in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (6.0)
# Requirement already satisfied: fsspec in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (2023.1.0)
# Requirement already satisfied: pycryptodome in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (3.17)
# Requirement already satisfied: typing-extensions in ./venv/lib/python3.7/site-packages (from gradio==3.19.0) (4.4.0)
# Requirement already satisfied: jsonschema>=3.0 in ./venv/lib/python3.7/site-packages (from altair>=4.2.0->gradio==3.19.0) (4.17.3)
# Requirement already satisfied: entrypoints in ./venv/lib/python3.7/site-packages (from altair>=4.2.0->gradio==3.19.0) (0.4)
# Requirement already satisfied: toolz in ./venv/lib/python3.7/site-packages (from altair>=4.2.0->gradio==3.19.0) (0.12.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in ./venv/lib/python3.7/site-packages (from httpx->gradio==3.19.0) (0.16.3)
# Requirement already satisfied: certifi in ./venv/lib/python3.7/site-packages (from httpx->gradio==3.19.0) (2022.12.7)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in ./venv/lib/python3.7/site-packages (from httpx->gradio==3.19.0) (1.5.0)
# Requirement already satisfied: sniffio in ./venv/lib/python3.7/site-packages (from httpx->gradio==3.19.0) (1.3.0)
# Collecting charset-normalizer<3.0,>=2.0
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./venv/lib/python3.7/site-packages (from aiohttp->gradio==3.19.0) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.7/site-packages (from aiohttp->gradio==3.19.0) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.7/site-packages (from aiohttp->gradio==3.19.0) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.7/site-packages (from aiohttp->gradio==3.19.0) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./venv/lib/python3.7/site-packages (from aiohttp->gradio==3.19.0) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.7/site-packages (from aiohttp->gradio==3.19.0) (22.2.0)
# Requirement already satisfied: asynctest==0.13.0; python_version < "3.8" in ./venv/lib/python3.7/site-packages (from aiohttp->gradio==3.19.0) (0.13.0)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.7/site-packages (from requests->gradio==3.19.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./venv/lib/python3.7/site-packages (from requests->gradio==3.19.0) (1.26.14)
# Requirement already satisfied: click>=7.0 in ./venv/lib/python3.7/site-packages (from uvicorn->gradio==3.19.0) (8.1.3)
# Requirement already satisfied: h11>=0.8 in ./venv/lib/python3.7/site-packages (from uvicorn->gradio==3.19.0) (0.14.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./venv/lib/python3.7/site-packages (from matplotlib->gradio==3.19.0) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.7/site-packages (from matplotlib->gradio==3.19.0) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.7/site-packages (from matplotlib->gradio==3.19.0) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in ./venv/lib/python3.7/site-packages (from matplotlib->gradio==3.19.0) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.7/site-packages (from matplotlib->gradio==3.19.0) (23.0)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.7/site-packages (from matplotlib->gradio==3.19.0) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in ./venv/lib/python3.7/site-packages (from pandas->gradio==3.19.0) (2022.7.1)
# Requirement already satisfied: six>=1.4.0 in ./venv/lib/python3.7/site-packages (from python-multipart->gradio==3.19.0) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.7/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.19.0) (0.1.2)
# Requirement already satisfied: linkify-it-py~=1.0; extra == "linkify" in ./venv/lib/python3.7/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.19.0) (1.0.3)
# Requirement already satisfied: starlette==0.22.0 in ./venv/lib/python3.7/site-packages (from fastapi->gradio==3.19.0) (0.22.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in ./venv/lib/python3.7/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.19.0) (6.0.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in ./venv/lib/python3.7/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.19.0) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in ./venv/lib/python3.7/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.19.0) (5.10.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./venv/lib/python3.7/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.19.0) (0.19.3)
# Requirement already satisfied: anyio<5.0,>=3.0 in ./venv/lib/python3.7/site-packages (from httpcore<0.17.0,>=0.15.0->httpx->gradio==3.19.0) (3.6.2)
# Requirement already satisfied: uc-micro-py in ./venv/lib/python3.7/site-packages (from linkify-it-py~=1.0; extra == "linkify"->markdown-it-py[linkify]>=2.0.0->gradio==3.19.0) (1.0.1)
# Requirement already satisfied: zipp>=0.5 in ./venv/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema>=3.0->altair>=4.2.0->gradio==3.19.0) (3.12.0)
# Installing collected packages: gradio, charset-normalizer
#   Attempting uninstall: gradio
#     Found existing installation: gradio 3.16.2
#     Uninstalling gradio-3.16.2:
#       Successfully uninstalled gradio-3.16.2
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.0.1
#     Uninstalling charset-normalizer-3.0.1:
#       Successfully uninstalled charset-normalizer-3.0.1
# Successfully installed charset-normalizer-2.1.1 gradio-3.19.0
# WARNING: You are using pip version 20.1.1; however, version 23.0.1 is available.
# You should consider upgrading via the '/kaggle/stable-diffusion-webui/venv/bin/python3 -m pip install --upgrade pip' command.
# Python 3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:53)
# [GCC 9.4.0]
# Commit hash: 22bcc7be428c94e9408f589966c2040187245d81
# Installing requirements for Web UI
#
#                         -------------
#
# __/\\\\\\\\\\\\\____/\\\\____________/\\\\____/\\\\\\\\\_____
#  _\/\\\/////////\\\_\/\\\\\\________/\\\\\\__/\\\///////\\\___
#   _\/\\\_______\/\\\_\/\\\//\\\____/\\\//\\\_\///______\//\\\__
#    _\/\\\\\\\\\\\\\/__\/\\\\///\\\/\\\/_\/\\\___________/\\\/___
#     _\/\\\/////////____\/\\\__\///\\\/___\/\\\________/\\\//_____
#      _\/\\\_____________\/\\\____\///_____\/\\\_____/\\\//________
#       _\/\\\_____________\/\\\_____________\/\\\___/\\\/___________
#        _\/\\\_____________\/\\\_____________\/\\\__/\\\\\\\\\\\\\\\_
#         _\///______________\///______________\///__\///////////////__
#
#
#                           Runtime Edition
#
#         PM2 is a Production Process Manager for Node.js applications
#                      with a built-in Load Balancer.
#
#                 Start and Daemonize any application:
#                 $ pm2 start app.js
#
#                 Load Balance 4 instances of api.js:
#                 $ pm2 start api.js -i 4
#
#                 Monitor in production:
#                 $ pm2 monitor
#
#                 Make pm2 auto-boot at server restart:
#                 $ pm2 startup
#
#                 To go further checkout:
#                 http://pm2.io/
#
#
#                         -------------
#
# [PM2] Spawning PM2 daemon with pm2_home=/root/.pm2
# [PM2] PM2 Successfully daemonized
# [TAILING] Tailing last 15 lines for [all] processes (change the value with --lines option)
# /root/.pm2/pm2.log last 15 lines:
# PM2        | 2023-04-01T13:30:39: PM2 log: --- New PM2 Daemon started ----------------------------------------------------
# PM2        | 2023-04-01T13:30:39: PM2 log: Time                 : Sat Apr 01 2023 13:30:39 GMT+0000 (Coordinated Universal Time)
# PM2        | 2023-04-01T13:30:39: PM2 log: PM2 version          : 5.3.0
# PM2        | 2023-04-01T13:30:39: PM2 log: Node.js version      : 18.12.1
# PM2        | 2023-04-01T13:30:39: PM2 log: Current arch         : x64
# PM2        | 2023-04-01T13:30:39: PM2 log: PM2 home             : /root/.pm2
# PM2        | 2023-04-01T13:30:39: PM2 log: PM2 PID file         : /root/.pm2/pm2.pid
# PM2        | 2023-04-01T13:30:39: PM2 log: RPC socket file      : /root/.pm2/rpc.sock
# PM2        | 2023-04-01T13:30:39: PM2 log: BUS socket file      : /root/.pm2/pub.sock
# PM2        | 2023-04-01T13:30:39: PM2 log: Application log path : /root/.pm2/logs
# PM2        | 2023-04-01T13:30:39: PM2 log: Worker Interval      : 30000
# PM2        | 2023-04-01T13:30:39: PM2 log: Process dump file    : /root/.pm2/dump.pm2
# PM2        | 2023-04-01T13:30:39: PM2 log: Concurrent actions   : 2
# PM2        | 2023-04-01T13:30:39: PM2 log: SIGTERM timeout      : 1600
# PM2        | 2023-04-01T13:30:39: PM2 log: ===============================================================================
#
# Installing requirements for Prompt Travel to generate video
#
# Installing sd-webui-controlnet requirement: svglib
#
# Launching Web UI with arguments: --disable-safe-unpickle --deepdanbooru --share --skip-torch-cuda-test --xformers --api --listen --lowram --no-half-vae --disable-console-progressbars
# Error loading script: controlnet_travel.py
# Traceback (most recent call last):
#   File "/kaggle/stable-diffusion-webui/modules/scripts.py", line 256, in load_scripts
#     script_module = script_loading.load_module(scriptfile.path)
#   File "/kaggle/stable-diffusion-webui/modules/script_loading.py", line 11, in load_module
#     module_spec.loader.exec_module(module)
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/kaggle/stable-diffusion-webui/extensions/stable-diffusion-webui-prompt-travel/scripts/controlnet_travel.py", line 517
#     interp_fn: Callable = None
#                              ^
# SyntaxError: annotated name 'interp_fn' can't be global
#
# Checkpoint AbyssOrangeMix2_nsfw.safetensors not found; loading fallback Anything-V4.5.safetensors
# Calculating sha256 for /kaggle/stable-diffusion-webui/models/Stable-diffusion/Anything-V4.5.safetensors: a504b5b137246d210c44e3076f3fb65ffe59ed0f1e0178d2a21856663001bd01
# Loading weights [a504b5b137] from /kaggle/stable-diffusion-webui/models/Stable-diffusion/Anything-V4.5.safetensors
# Creating model from config: /kaggle/stable-diffusion-webui/configs/v1-inference.yaml
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# Downloading (…)olve/main/vocab.json: 100%|███| 961k/961k [00:00<00:00, 7.08MB/s]
# Downloading (…)olve/main/merges.txt: 100%|███| 525k/525k [00:00<00:00, 4.76MB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████| 389/389 [00:00<00:00, 160kB/s]
# Downloading (…)okenizer_config.json: 100%|██████| 905/905 [00:00<00:00, 330kB/s]
# Downloading (…)lve/main/config.json: 100%|██| 4.52k/4.52k [00:00<00:00, 366kB/s]
# Loading VAE weights specified in settings: /kaggle/stable-diffusion-webui/models/Stable-diffusion/orangemix.vae.pt
# Applying xformers cross attention optimization.
# Textual inversion embeddings loaded(1): EasyNegative
# Model loaded in 52.4s (calculate hash: 28.7s, load weights from disk: 9.9s, create model: 3.0s, apply weights to model: 3.9s, apply half(): 1.5s, load VAE: 4.6s, move model to device: 0.7s).
# Running on local URL:  http://0.0.0.0:7860
# Running on public URL: https://e5387fa9ffe33bfa8a.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# Startup time: 66.8s (import torch: 1.4s, import gradio: 1.7s, import ldm: 0.8s, other imports: 1.4s, setup codeformer: 0.3s, load scripts: 2.1s, load SD checkpoint: 52.4s, create ui: 4.6s, gradio launch: 2.0s, scripts app_started_callback: 0.1s).
# 100%|███████████████████████████████████████████| 24/24 [00:15<00:00,  1.57it/s]
# 100%|███████████████████████████████████████████| 24/24 [00:06<00:00,  3.81it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.79it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.81it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.80it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.79it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.78it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.76it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.74it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.70it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.66it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.62it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.63it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.61it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.59it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.57it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.57it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.57it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.54it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.52it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.53it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.50it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.50it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.47it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.45it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.44it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.43it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.43it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.43it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.44it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.45it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.46it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.45it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:05<00:00,  3.46it/s]

# %% [markdown]
# ### 交流群 632428790 （遇到问题可以找群主或者管理员解决）

# %%
#自动保存
autosave()

# %% [markdown]
# ## 如需保存图片文件或者训练文件，点击页面顶端的Cancel Run，将输出目录的tar解压包下载即可
